# %%
import pandas as pd
import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
edad = df["usuaria_edad"]
dist = edad.value_counts()
plt.bar(dist.index, dist.values)
plt.xlim(0,100)
plt.show()
# Out:
# <ipython-input-5-3415157f6e28>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
conteo = df["usuaria_estado_civil"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-6-30a838e6dccb>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
conteo = df["Año"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-8-9a39fc35a2ef>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
conteo = df["Mes"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-9-b1e6e060ac07>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
conteo = df["Año y mes"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-10-cea1d2dfaeca>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/CONJUNTO DE DATOS/1atenciones_abogadas_de_las_mujeres (3) - atenciones_abogadas_de_las_mujeres (3).csv.csv"
df = pd.read_csv(path)
df_filtrado = df.query("usuaria_edad <= 160")
print(df_filtrado["usuaria_edad"])
plt.boxplot(df_filtrado["usuaria_edad"])
plt.show()
# Out:
# <ipython-input-13-d4d991ac9ed3>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# 0         33.0
# 1         26.0
# 2         25.0
# 3         55.0
# 4         33.0
#           ...
# 121990    50.0
# 121991    31.0
# 121992    20.0
# 121993    26.0
# 121994    31.0
# Name: usuaria_edad, Length: 119978, dtype: float64
